# %%
import pandas as pd        
import re

# %%
df = pd.read_csv("Hospital_Locations.csv")

# %%
df
# Out:
#               X          Y  FID  \
# 0    144.983399 -37.809681    1
# 1    145.149300 -37.951400    2
# 2    145.344653 -38.034580    3
# 3    143.832286 -37.540553    4
# 4    145.143379 -38.148189    5
# ..          ...        ...  ...
# 320  142.857700 -35.500500  321
# 321  144.887100 -37.791100  322
# 322  145.018500 -37.961000  323
# 323  144.886976 -37.791622  324
# 324  144.977380 -37.811873  325
#
#                                              LabelName  \
# 0               East Melbourne Specialist Day Hospital
# 1                           Windsor Avenue Day Surgery
# 2               Hyperbaric Health Wound Centre Berwick
# 3                        Ballarat Day Procedure Centre
# 4          Bayside Day Procedure and Specialist Centre
# ..                                                 ...
# 320  Mallee Track Health & Community Service (Sea L...
# 321                              Orygen Inpatient Unit
# 322                                Women's Sandringham
# ...

# %%
df['OpsName'].unique()
# Out:
# array(['EAST MELBOURNE DAY HOSPITAL', 'WINDSOR AVENUE DAY SURGERY',
#        'HYPERBARIC HEALTH - BERWICK', 'BALLARAT DAY PROCEDURE CENTRE',
#        'BAYSIDE DAY PROCEDURE CENTRE', 'BENDIGO DAY SURGERY',
#        'SURGICENTRE - BENTLEIGH', 'SURGICENTRE AND EYE -BERWICK',
#        'BRIGHTON PLASTIC SURGERY', 'BUNDOORA ENDOSCOPY CENTRE',
#        'CHESTERVILLE DAY HOSPITAL', 'COBURG ENDOSCOPY CENTRE',
#        'DANDENONG DAY SURGERY CENTRE', 'DAREBIN ENDOSCOPY SERVICES',
#        'DIAVERUM - DIAMOND VALLEY', 'DIAVERUM - NORTH MELBOURNE',
#        'EASTSIDE ENDOSCOPY CENTRE', 'ESSENDON DAY PROCEDURE CENTRE',
#        'GLEN EIRA DAY SURGERY', 'GLEN IRIS PRIVATE',
#        'HEIDELBERG ENDOSCOPY CENTRE', 'HOBSONS BAY ENDO - ALTONA',
#        'HOBSONS BAY ENDO - WERRIBEE', 'IVANHOE ENDOSCOPY CENTRE',
#        'JOLIMONT ENDOSCOPY CENTRE', 'MALVERN DIALYSIS CLINIC',
#        'MANNINGHAM DAY CENTRE', 'MELBOURNE DAY SURGERY CENTRE',
#        'MELBOURNE ENDOSCOPY CENTRE', 'MONASH IVF GEELONG',
# ...

# %%
df.isnull().sum()
# Out:
# X             0
# Y             0
# FID           0
# LabelName     0
# OpsName       0
# Type          0
# StreetNum     0
# RoadName      0
# RoadType      0
# RoadSuffix    0
# CampusCode    0
# LGAName       0
# LocalityNa    0
# Postcode      0
# VicgovRegi    0
# State         0
# ServiceNam    0
# dtype: int64

# %%
df_new = df[df["OpsName"].str.contains("HOSPITAL")]

# %%
df_new
# Out:
#               X          Y  FID  \
# 0    144.983399 -37.809681    1
# 10   145.056802 -37.960467   11
# 31   144.909380 -37.771154   32
# 37   144.982200 -37.873100   38
# 48   144.679748 -37.877485   49
# ..          ...        ...  ...
# 314  145.431300 -37.213900  315
# 315  145.351400 -37.756600  316
# 318  144.732700 -37.577200  319
# 319  146.939700 -36.078500  320
# 320  142.857700 -35.500500  321
#
#                                              LabelName  \
# 0               East Melbourne Specialist Day Hospital
# 10                           Chesterville Day Hospital
# 31                              Northwest Day Hospital
# 37                               St Kilda Day Hospital
# 48                    Westpoint Endoscopy Day Hospital
# ..                                                 ...
# 314                 Yea and District Memorial Hospital
# 315                                Yarra Ranges Health
# 318                               Sunbury Day Hospital
# ...

# %%
df_new['address'] = df_new.apply(lambda row: str(row['StreetNum']) +' ' + row['RoadName'] + " "+ str(row['RoadType']) + " " + str(row['LGAName']),axis = 1)
# Out:
# C:\Users\manas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new = df_new[['X','Y','OpsName','Type','address']]

# %%
df_new.to_csv('vict_new_hospitals.csv', index=False)

# %%
df_new
# Out:
#               X          Y                         OpsName     Type  \
# 0    144.983399 -37.809681     EAST MELBOURNE DAY HOSPITAL  PRIVATE
# 10   145.056802 -37.960467       CHESTERVILLE DAY HOSPITAL  PRIVATE
# 31   144.909380 -37.771154          NORTHWEST DAY HOSPITAL  PRIVATE
# 37   144.982200 -37.873100           ST KILDA DAY HOSPITAL  PRIVATE
# 48   144.679748 -37.877485    WESTPOINT ENDOSCOPY HOSPITAL  PRIVATE
# ..          ...        ...                             ...      ...
# 314  145.431300 -37.213900             YEA PUBLIC HOSPITAL   PUBLIC
# 315  145.351400 -37.756600        LILYDALE PUBLIC HOSPITAL   PUBLIC
# 318  144.732700 -37.577200         SUNBURY PUBLIC HOSPITAL   PUBLIC
# 319  146.939700 -36.078500     ALBURY BASE PUBLIC HOSPITAL   PUBLIC
# 320  142.857700 -35.500500  SEA LAKE AND DISTRICT HOSPITAL   PUBLIC
#
#                                 address
# 0         23 CLARENDON STREET MELBOURNE
# 10        28 CHESTERVILLE ROAD KINGSTON
# ...
